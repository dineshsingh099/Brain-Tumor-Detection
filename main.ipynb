# %% [markdown]
# <a href="https://colab.research.google.com/github/dineshsingh099/Brain-Tumor-Detection/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Brain Tumor Detection
# Brain Tumor Detection is a deep learning project that uses MRI images to identify whether a brain tumor is present or not. The system uses a CNN model to automatically analyze images and assist in early diagnosis.

# %%
from IPython.display import Image, display
display(Image(filename='/content/img.png', width=700))

# %% [markdown]
# ## 1. Problem Definition (Business Understanding Phase)
#
# The objective of this project is to identify the presence of brain tumors from MRI images.
# This is a medical image classification problem solved using deep learning techniques.

# %% [markdown]
# ### Google Drive Mount

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Import Required Libraries

# %%
import os
import random
import cv2
import matplotlib.pyplot as plt
from sklearn.utils import shuffle

# %% [markdown]
# ## 2. Data Collection (Data Acquisition Phase)
#
# The dataset consists of MRI brain images categorized into multiple tumor classes.
# The data is organized into Training and Testing directories, where each class is stored in a separate folder.

# %% [markdown]
# ### Training and Testing Directories

# %%
train_dir = "/content/Training"
test_dir  = "/content/Testing"

# %% [markdown]
# ### Training Data Preparation

# %%
train_paths = []
train_labels = []

for label in os.listdir(train_dir):
    label_path = os.path.join(train_dir, label)
    if os.path.isdir(label_path):
        for image in os.listdir(label_path):
            train_paths.append(os.path.join(label_path, image))
            train_labels.append(label)

train_paths, train_labels = shuffle(train_paths, train_labels, random_state=42)

# %% [markdown]
# ### Test Data Preparation

# %%
test_paths = []
test_labels = []

for label in os.listdir(test_dir):
    label_path = os.path.join(test_dir, label)
    if os.path.isdir(label_path):
        for image in os.listdir(label_path):
            test_paths.append(os.path.join(label_path, image))
            test_labels.append(label)

test_paths, test_labels = shuffle(test_paths, test_labels, random_state=42)

# %% [markdown]
# ## 3. Data Visualization (Exploratory Data Analysis)

# %%
random_indices = random.sample(range(len(train_paths)), 10)

fig, axes = plt.subplots(2, 5, figsize=(15, 6))
axes = axes.ravel()

for i, idx in enumerate(random_indices):
    img = plt.imread(train_paths[idx])
    label = train_labels[idx]

    axes[i].imshow(img)
    axes[i].set_title(label, fontsize=10)
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Data Preprocessing Pipeline

# %%
def augment_image(image):
    pass

# %%
def load_images(paths):
    pass

# %%
def encode_class_labels(labels):
    pass

# %%
def data_batch_generator(image_paths, labels, batch_size=12, epochs=1):
    pass
